# %% [markdown]
# ## Data

# %%
import json
with open('../data/teczno/GeoJSON-file/North-Carolina-2014.geojson') as f:
    data = json.load(f)
data = data['features']

# %%
data[0]['properties']
# Out:
# {'COUNTY_ID': 11,
#  'COUNTY_NAM': 'BUNCOMBE',
#  'ENR_DESC': '09.1_MURPHY-OAKLEY COMMUNITY CENTER',
#  'GID': 1,
#  'OF_PREC_ID': None,
#  'PREC_ID': '09.1',
#  'area_km2': 7,
#  'asian_pop': 18,
#  'black_pop': 994,
#  'college_pop': 1539,
#  'con_blue_votes': 897,
#  'con_contested': 'True',
#  'con_districts': 10,
#  'con_red_votes': 386,
#  'county_name': 'BUNCOMBE',
#  'diploma_pop': 892,
#  'education_pop': 3085,
#  'graduate_pop': 304,
#  'hispanic_pop': 192,
#  'median_age': 40,
#  'median_income': 34526,
#  'other_pop': 115,
#  'population': 4298,
#  'precinct_id': '09.1',
#  'school_pop': 351,
#  'sen_blue': 899,
#  'sen_red': 331,
#  'sldl_blue_votes': 1008,
#  'sldl_contested': 'No',
#  'sldl_districts': 114,
#  'sldl_red_votes': None,
#  'sldu_blue_votes': 916,
#  'sldu_contested': 'Yes',
#  'sldu_districts': 49,
#  'sldu_red_votes': 367,
#  'white_pop': 2979}

# %% [markdown]
# ## Efficiency Gap

# %%
def votes_cast_for_senator(pt):
    red  = pt['properties']['sen_red']
    blue = pt['properties']['sen_blue']
    return (red, blue)

# %%
def threshold(votes):
    if votes[0] == votes[1]:
        raise Exception("The Efficiency Gap is undefined in the case of a tie")
    half = sum(votes)/2
    if round(half) == half:
        thresh = (half) + 1
    else:
        thresh = round(half)
    return int(thresh)

# %%
def wasted_votes(pt):
    (red, blue) = votes_cast_for_senator(pt)
    if red==blue:
        return (0,0)
    
    thresh = threshold((red, blue))
    if red>thresh:
        red_wasted = red - thresh
        blue_wasted = blue
    else:
        blue_wasted = blue - thresh
        red_wasted = red
    
    return (red_wasted, blue_wasted)

# %%
for pt in data:
    (red, blue) = votes_cast_for_senator(pt)
    thresh = threshold((red, blue))
    (red_wasted, blue_wasted) = wasted_votes(pt)
    
    print(f"With {red} red votes and {blue} blue votes, {thresh} votes are needed to win.")
    print(f"Red wasted {red_wasted} votes and blue wasted {blue_wasted} votes.\n")
# Out:
# With 331 red votes and 899 blue votes, 616 votes are needed to win.
# Red wasted 331 votes and blue wasted 283 votes.
#
# With 614 red votes and 473 blue votes, 544 votes are needed to win.
# Red wasted 70 votes and blue wasted 473 votes.
#
# With 132 red votes and 652 blue votes, 393 votes are needed to win.
# Red wasted 132 votes and blue wasted 259 votes.
#
# With 73 red votes and 839 blue votes, 457 votes are needed to win.
# Red wasted 73 votes and blue wasted 382 votes.
#
# With 726 red votes and 464 blue votes, 596 votes are needed to win.
# Red wasted 130 votes and blue wasted 464 votes.
#
# With 19 red votes and 324 blue votes, 172 votes are needed to win.
# Red wasted 19 votes and blue wasted 152 votes.
#
# With 231 red votes and 466 blue votes, 348 votes are needed to win.
# Red wasted 231 votes and blue wasted 118 votes.
#
# With 358 red votes and 309 blue votes, 334 votes are needed to win.
# Red wasted 24 votes and blue wasted 309 votes.
#
# With 423 red votes and 432 blue votes, 428 votes are needed to win.
# Red wasted 423 votes and blue wasted 4 votes.
#
# With 354 red votes and 549 blue votes, 452 votes are needed to win.
# Red wasted 354 votes and blue wasted 97 votes.
#
# With 129 red votes and 1163 blue votes, 647 votes are needed to win.
# Red wasted 129 votes and blue wasted 516 votes.
#
# With 595 red votes and 325 blue votes, 461 votes are needed to win.
# Red wasted 134 votes and blue wasted 325 votes.
#
# With 533 red votes and 778 blue votes, 656 votes are needed to win.
# Red wasted 533 votes and blue wasted 122 votes.
#
# With 1261 red votes and 1354 blue votes, 1308 votes are needed to win.
# Red wasted 1261 votes and blue wasted 46 votes.
#
# With 1169 red votes and 686 blue votes, 928 votes are needed to win.
# Red wasted 241 votes and blue wasted 686 votes.
#
# With 181 red votes and 408 blue votes, 294 votes are needed to win.
# Red wasted 181 votes and blue wasted 114 votes.
#
# With 723 red votes and 575 blue votes, 650 votes are needed to win.
# Red wasted 73 votes and blue wasted 575 votes.
#
# With 881 red votes and 394 blue votes, 638 votes are needed to win.
# Red wasted 243 votes and blue wasted 394 votes.
#
# With 1359 red votes and 1008 blue votes, 1184 votes are needed to win.
# Red wasted 175 votes and blue wasted 1008 votes.
#
# With 264 red votes and 340 blue votes, 303 votes are needed to win.
# Red wasted 264 votes and blue wasted 37 votes.
#
# With 314 red votes and 536 blue votes, 426 votes are needed to win.
# Red wasted 314 votes and blue wasted 110 votes.
#
# With 613 red votes and 434 blue votes, 524 votes are needed to win.
# Red wasted 89 votes and blue wasted 434 votes.
#
# With 667 red votes and 452 blue votes, 560 votes are needed to win.
# Red wasted 107 votes and blue wasted 452 votes.
#
# With 1084 red votes and 658 blue votes, 872 votes are needed to win.
# Red wasted 212 votes and blue wasted 658 votes.
#
# With 1484 red votes and 840 blue votes, 1163 votes are needed to win.
# Red wasted 321 votes and blue wasted 840 votes.
#
# With 1181 red votes and 597 blue votes, 890 votes are needed to win.
# Red wasted 291 votes and blue wasted 597 votes.
#
# With 1475 red votes and 714 blue votes, 1094 votes are needed to win.
# Red wasted 381 votes and blue wasted 714 votes.
#
# With 711 red votes and 889 blue votes, 801 votes are needed to win.
# Red wasted 711 votes and blue wasted 88 votes.
#
# With 1130 red votes and 497 blue votes, 814 votes are needed to win.
# Red wasted 316 votes and blue wasted 497 votes.
#
# With 1164 red votes and 831 blue votes, 998 votes are needed to win.
# Red wasted 166 votes and blue wasted 831 votes.
#
# With 176 red votes and 370 blue votes, 274 votes are needed to win.
# Red wasted 176 votes and blue wasted 96 votes.
#
# With 397 red votes and 210 blue votes, 304 votes are needed to win.
# Red wasted 93 votes and blue wasted 210 votes.
#
# With 731 red votes and 442 blue votes, 586 votes are needed to win.
# Red wasted 145 votes and blue wasted 442 votes.
#
# With 363 red votes and 266 blue votes, 314 votes are needed to win.
# Red wasted 49 votes and blue wasted 266 votes.
#
# With 351 red votes and 238 blue votes, 294 votes are needed to win.
# Red wasted 57 votes and blue wasted 238 votes.
#
# With 376 red votes and 180 blue votes, 279 votes are needed to win.
# Red wasted 97 votes and blue wasted 180 votes.
#
# With 168 red votes and 202 blue votes, 186 votes are needed to win.
# Red wasted 168 votes and blue wasted 16 votes.
#
# With 342 red votes and 126 blue votes, 235 votes are needed to win.
# Red wasted 107 votes and blue wasted 126 votes.
#
# With 185 red votes and 131 blue votes, 159 votes are needed to win.
# Red wasted 26 votes and blue wasted 131 votes.
#
# With 99 red votes and 136 blue votes, 118 votes are needed to win.
# Red wasted 99 votes and blue wasted 18 votes.
#
# With 214 red votes and 32 blue votes, 124 votes are needed to win.
# Red wasted 90 votes and blue wasted 32 votes.
#
# With 250 red votes and 523 blue votes, 386 votes are needed to win.
# Red wasted 250 votes and blue wasted 137 votes.
#
# With 92 red votes and 209 blue votes, 150 votes are needed to win.
# Red wasted 92 votes and blue wasted 59 votes.
#
# With 133 red votes and 119 blue votes, 127 votes are needed to win.
# Red wasted 6 votes and blue wasted 119 votes.
#
# With 416 red votes and 173 blue votes, 294 votes are needed to win.
# Red wasted 122 votes and blue wasted 173 votes.
#
# With 33 red votes and 164 blue votes, 98 votes are needed to win.
# Red wasted 33 votes and blue wasted 66 votes.
#
# With 509 red votes and 172 blue votes, 340 votes are needed to win.
# Red wasted 169 votes and blue wasted 172 votes.
#
# With 103 red votes and 36 blue votes, 70 votes are needed to win.
# Red wasted 33 votes and blue wasted 36 votes.
#
# With 190 red votes and 151 blue votes, 170 votes are needed to win.
# Red wasted 20 votes and blue wasted 151 votes.
#
# With 229 red votes and 97 blue votes, 164 votes are needed to win.
# Red wasted 65 votes and blue wasted 97 votes.
#
# With 29 red votes and 204 blue votes, 116 votes are needed to win.
# Red wasted 29 votes and blue wasted 88 votes.
#
# With 82 red votes and 310 blue votes, 197 votes are needed to win.
# Red wasted 82 votes and blue wasted 113 votes.
#
# With 14 red votes and 127 blue votes, 70 votes are needed to win.
# Red wasted 14 votes and blue wasted 57 votes.
#
# With 90 red votes and 11 blue votes, 50 votes are needed to win.
# Red wasted 40 votes and blue wasted 11 votes.
#
# With 247 red votes and 75 blue votes, 162 votes are needed to win.
# Red wasted 85 votes and blue wasted 75 votes.
#
# With 161 red votes and 25 blue votes, 94 votes are needed to win.
# Red wasted 67 votes and blue wasted 25 votes.
#
# With 436 red votes and 198 blue votes, 318 votes are needed to win.
# Red wasted 118 votes and blue wasted 198 votes.
#
# With 94 red votes and 6 blue votes, 51 votes are needed to win.
# Red wasted 43 votes and blue wasted 6 votes.
#
# With 112 red votes and 7 blue votes, 60 votes are needed to win.
# Red wasted 52 votes and blue wasted 7 votes.
#
# With 85 red votes and 20 blue votes, 52 votes are needed to win.
# Red wasted 33 votes and blue wasted 20 votes.
#
# With 98 red votes and 11 blue votes, 54 votes are needed to win.
# Red wasted 44 votes and blue wasted 11 votes.
#
# With 202 red votes and 60 blue votes, 132 votes are needed to win.
# Red wasted 70 votes and blue wasted 60 votes.
#
# With 25 red votes and 8 blue votes, 16 votes are needed to win.
# Red wasted 9 votes and blue wasted 8 votes.
#
# With 163 red votes and 28 blue votes, 96 votes are needed to win.
# Red wasted 67 votes and blue wasted 28 votes.
#
# With 998 red votes and 318 blue votes, 659 votes are needed to win.
# Red wasted 339 votes and blue wasted 318 votes.
#
# With 1149 red votes and 380 blue votes, 764 votes are needed to win.
# Red wasted 385 votes and blue wasted 380 votes.
#
# With 759 red votes and 329 blue votes, 545 votes are needed to win.
# Red wasted 214 votes and blue wasted 329 votes.
#
# With 248 red votes and 63 blue votes, 156 votes are needed to win.
# Red wasted 92 votes and blue wasted 63 votes.
#
# With 251 red votes and 153 blue votes, 203 votes are needed to win.
# Red wasted 48 votes and blue wasted 153 votes.
#
# With 399 red votes and 108 blue votes, 254 votes are needed to win.
# Red wasted 145 votes and blue wasted 108 votes.
#
# With 474 red votes and 193 blue votes, 334 votes are needed to win.
# Red wasted 140 votes and blue wasted 193 votes.
#
# With 593 red votes and 216 blue votes, 404 votes are needed to win.
# Red wasted 189 votes and blue wasted 216 votes.
#
# With 243 red votes and 135 blue votes, 190 votes are needed to win.
# Red wasted 53 votes and blue wasted 135 votes.
#
# With 335 red votes and 91 blue votes, 214 votes are needed to win.
# Red wasted 121 votes and blue wasted 91 votes.
#
# With 419 red votes and 109 blue votes, 265 votes are needed to win.
# Red wasted 154 votes and blue wasted 109 votes.
#
# With 313 red votes and 190 blue votes, 252 votes are needed to win.
# Red wasted 61 votes and blue wasted 190 votes.
#
# With 69 red votes and 68 blue votes, 68 votes are needed to win.
# Red wasted 1 votes and blue wasted 68 votes.
#
# With 331 red votes and 719 blue votes, 526 votes are needed to win.
# Red wasted 331 votes and blue wasted 193 votes.
#
# With 222 red votes and 690 blue votes, 457 votes are needed to win.
# Red wasted 222 votes and blue wasted 233 votes.
#
# With 165 red votes and 455 blue votes, 311 votes are needed to win.
# Red wasted 165 votes and blue wasted 144 votes.
#
# With 370 red votes and 604 blue votes, 488 votes are needed to win.
# Red wasted 370 votes and blue wasted 116 votes.
#
# With 92 red votes and 448 blue votes, 271 votes are needed to win.
# Red wasted 92 votes and blue wasted 177 votes.
#
# With 340 red votes and 191 blue votes, 266 votes are needed to win.
# Red wasted 74 votes and blue wasted 191 votes.
#
# With 174 red votes and 296 blue votes, 236 votes are needed to win.
# Red wasted 174 votes and blue wasted 60 votes.
#
# With 139 red votes and 303 blue votes, 222 votes are needed to win.
# Red wasted 139 votes and blue wasted 81 votes.
#
# With 159 red votes and 185 blue votes, 173 votes are needed to win.
# Red wasted 159 votes and blue wasted 12 votes.
#
# With 1028 red votes and 675 blue votes, 852 votes are needed to win.
# Red wasted 176 votes and blue wasted 675 votes.
#
# With 94 red votes and 258 blue votes, 177 votes are needed to win.
# Red wasted 94 votes and blue wasted 81 votes.
#
# With 505 red votes and 345 blue votes, 426 votes are needed to win.
# Red wasted 79 votes and blue wasted 345 votes.
#
# With 102 red votes and 258 blue votes, 181 votes are needed to win.
# Red wasted 102 votes and blue wasted 77 votes.
#
# With 221 red votes and 127 blue votes, 175 votes are needed to win.
# Red wasted 46 votes and blue wasted 127 votes.
#
# With 160 red votes and 30 blue votes, 96 votes are needed to win.
# Red wasted 64 votes and blue wasted 30 votes.
#
# With 123 red votes and 16 blue votes, 70 votes are needed to win.
# Red wasted 53 votes and blue wasted 16 votes.
#
# With 204 red votes and 51 blue votes, 128 votes are needed to win.
# Red wasted 76 votes and blue wasted 51 votes.
#
# With 122 red votes and 53 blue votes, 88 votes are needed to win.
# Red wasted 34 votes and blue wasted 53 votes.
#
# With 305 red votes and 143 blue votes, 225 votes are needed to win.
# Red wasted 80 votes and blue wasted 143 votes.
#
# With 164 red votes and 41 blue votes, 102 votes are needed to win.
# Red wasted 62 votes and blue wasted 41 votes.
#
# With 63 red votes and 5 blue votes, 35 votes are needed to win.
# Red wasted 28 votes and blue wasted 5 votes.
#
# With 127 red votes and 49 blue votes, 89 votes are needed to win.
# Red wasted 38 votes and blue wasted 49 votes.
#
# With 399 red votes and 261 blue votes, 331 votes are needed to win.
# Red wasted 68 votes and blue wasted 261 votes.
#
# With 347 red votes and 184 blue votes, 266 votes are needed to win.
# Red wasted 81 votes and blue wasted 184 votes.
#
# With 425 red votes and 270 blue votes, 348 votes are needed to win.
# Red wasted 77 votes and blue wasted 270 votes.
#
# With 298 red votes and 96 blue votes, 198 votes are needed to win.
# Red wasted 100 votes and blue wasted 96 votes.
#
# With 588 red votes and 182 blue votes, 386 votes are needed to win.
# Red wasted 202 votes and blue wasted 182 votes.
#
# With 187 red votes and 79 blue votes, 134 votes are needed to win.
# Red wasted 53 votes and blue wasted 79 votes.
#
# With 109 red votes and 113 blue votes, 112 votes are needed to win.
# Red wasted 109 votes and blue wasted 1 votes.
#
# With 225 red votes and 155 blue votes, 191 votes are needed to win.
# Red wasted 34 votes and blue wasted 155 votes.
#
# With 248 red votes and 128 blue votes, 189 votes are needed to win.
# Red wasted 59 votes and blue wasted 128 votes.
#
# With 112 red votes and 204 blue votes, 159 votes are needed to win.
# Red wasted 112 votes and blue wasted 45 votes.
#
# With 138 red votes and 161 blue votes, 150 votes are needed to win.
# Red wasted 138 votes and blue wasted 11 votes.
#
# With 185 red votes and 153 blue votes, 170 votes are needed to win.
# Red wasted 15 votes and blue wasted 153 votes.
#
# With 214 red votes and 210 blue votes, 213 votes are needed to win.
# Red wasted 1 votes and blue wasted 210 votes.
#
# With 217 red votes and 109 blue votes, 164 votes are needed to win.
# Red wasted 53 votes and blue wasted 109 votes.
#
# With 460 red votes and 199 blue votes, 330 votes are needed to win.
# Red wasted 130 votes and blue wasted 199 votes.
#
# With 56 red votes and 258 blue votes, 158 votes are needed to win.
# Red wasted 56 votes and blue wasted 100 votes.
#
# With 427 red votes and 236 blue votes, 332 votes are needed to win.
# Red wasted 95 votes and blue wasted 236 votes.
#
# With 109 red votes and 227 blue votes, 169 votes are needed to win.
# Red wasted 109 votes and blue wasted 58 votes.
#
# With 290 red votes and 164 blue votes, 228 votes are needed to win.
# Red wasted 62 votes and blue wasted 164 votes.
#
# With 229 red votes and 192 blue votes, 210 votes are needed to win.
# Red wasted 19 votes and blue wasted 192 votes.
#
# With 432 red votes and 78 blue votes, 256 votes are needed to win.
# Red wasted 176 votes and blue wasted 78 votes.
#
# With 184 red votes and 163 blue votes, 174 votes are needed to win.
# Red wasted 10 votes and blue wasted 163 votes.
#
# With 499 red votes and 209 blue votes, 355 votes are needed to win.
# Red wasted 144 votes and blue wasted 209 votes.
#
# With 328 red votes and 115 blue votes, 222 votes are needed to win.
# Red wasted 106 votes and blue wasted 115 votes.
#
# With 257 red votes and 140 blue votes, 198 votes are needed to win.
# Red wasted 59 votes and blue wasted 140 votes.
#
# With 155 red votes and 163 blue votes, 160 votes are needed to win.
# Red wasted 155 votes and blue wasted 3 votes.
#
# With 36 red votes and 183 blue votes, 110 votes are needed to win.
# Red wasted 36 votes and blue wasted 73 votes.
#
# With 89 red votes and 225 blue votes, 158 votes are needed to win.
# Red wasted 89 votes and blue wasted 67 votes.
#
# With 203 red votes and 274 blue votes, 238 votes are needed to win.
# Red wasted 203 votes and blue wasted 36 votes.
#
# With 108 red votes and 56 blue votes, 83 votes are needed to win.
# Red wasted 25 votes and blue wasted 56 votes.
#
# With 64 red votes and 76 blue votes, 71 votes are needed to win.
# Red wasted 64 votes and blue wasted 5 votes.
#
# With 384 red votes and 194 blue votes, 290 votes are needed to win.
# Red wasted 94 votes and blue wasted 194 votes.
#
# With 65 red votes and 92 blue votes, 78 votes are needed to win.
# Red wasted 65 votes and blue wasted 14 votes.
#
# With 203 red votes and 340 blue votes, 272 votes are needed to win.
# Red wasted 203 votes and blue wasted 68 votes.
#
# With 115 red votes and 170 blue votes, 142 votes are needed to win.
# Red wasted 115 votes and blue wasted 28 votes.
#
# With 136 red votes and 59 blue votes, 98 votes are needed to win.
# Red wasted 38 votes and blue wasted 59 votes.
#
# With 98 red votes and 118 blue votes, 109 votes are needed to win.
# Red wasted 98 votes and blue wasted 9 votes.
#
# With 181 red votes and 182 blue votes, 182 votes are needed to win.
# Red wasted 181 votes and blue wasted 0 votes.
#
# With 180 red votes and 271 blue votes, 226 votes are needed to win.
# Red wasted 180 votes and blue wasted 45 votes.
#
# With 457 red votes and 481 blue votes, 470 votes are needed to win.
# Red wasted 457 votes and blue wasted 11 votes.
#
# With 990 red votes and 190 blue votes, 591 votes are needed to win.
# Red wasted 399 votes and blue wasted 190 votes.
#
# With 1558 red votes and 466 blue votes, 1013 votes are needed to win.
# Red wasted 545 votes and blue wasted 466 votes.
#
# With 814 red votes and 255 blue votes, 534 votes are needed to win.
# Red wasted 280 votes and blue wasted 255 votes.
#
# With 89 red votes and 680 blue votes, 384 votes are needed to win.
# Red wasted 89 votes and blue wasted 296 votes.
#
# With 308 red votes and 234 blue votes, 272 votes are needed to win.
# Red wasted 36 votes and blue wasted 234 votes.
#
# With 232 red votes and 82 blue votes, 158 votes are needed to win.
# Red wasted 74 votes and blue wasted 82 votes.
#
# With 824 red votes and 242 blue votes, 534 votes are needed to win.
# Red wasted 290 votes and blue wasted 242 votes.
#
# With 730 red votes and 266 blue votes, 499 votes are needed to win.
# Red wasted 231 votes and blue wasted 266 votes.
#
# With 374 red votes and 983 blue votes, 678 votes are needed to win.
# Red wasted 374 votes and blue wasted 305 votes.
#
# With 25 red votes and 555 blue votes, 291 votes are needed to win.
# Red wasted 25 votes and blue wasted 264 votes.
#
# With 29 red votes and 541 blue votes, 286 votes are needed to win.
# Red wasted 29 votes and blue wasted 255 votes.
#
# With 94 red votes and 876 blue votes, 486 votes are needed to win.
# Red wasted 94 votes and blue wasted 390 votes.
#
# With 172 red votes and 548 blue votes, 361 votes are needed to win.
# Red wasted 172 votes and blue wasted 187 votes.
#
# With 328 red votes and 504 blue votes, 417 votes are needed to win.
# Red wasted 328 votes and blue wasted 87 votes.
#
# With 546 red votes and 208 blue votes, 378 votes are needed to win.
# Red wasted 168 votes and blue wasted 208 votes.
#
# With 687 red votes and 558 blue votes, 622 votes are needed to win.
# Red wasted 65 votes and blue wasted 558 votes.
#
# With 563 red votes and 306 blue votes, 434 votes are needed to win.
# Red wasted 129 votes and blue wasted 306 votes.
#
# With 286 red votes and 211 blue votes, 248 votes are needed to win.
# Red wasted 38 votes and blue wasted 211 votes.
#
# With 582 red votes and 377 blue votes, 480 votes are needed to win.
# Red wasted 102 votes and blue wasted 377 votes.
#
# With 916 red votes and 506 blue votes, 712 votes are needed to win.
# Red wasted 204 votes and blue wasted 506 votes.
#
# With 973 red votes and 321 blue votes, 648 votes are needed to win.
# Red wasted 325 votes and blue wasted 321 votes.
#
# With 897 red votes and 347 blue votes, 623 votes are needed to win.
# Red wasted 274 votes and blue wasted 347 votes.
#
# With 609 red votes and 252 blue votes, 430 votes are needed to win.
# Red wasted 179 votes and blue wasted 252 votes.
#
# With 1235 red votes and 459 blue votes, 848 votes are needed to win.
# Red wasted 387 votes and blue wasted 459 votes.
#
# With 1172 red votes and 530 blue votes, 852 votes are needed to win.
# Red wasted 320 votes and blue wasted 530 votes.
#
# With 428 red votes and 383 blue votes, 406 votes are needed to win.
# Red wasted 22 votes and blue wasted 383 votes.
#
# With 742 red votes and 233 blue votes, 488 votes are needed to win.
# Red wasted 254 votes and blue wasted 233 votes.
#
# With 359 red votes and 271 blue votes, 316 votes are needed to win.
# Red wasted 43 votes and blue wasted 271 votes.
#
# With 886 red votes and 495 blue votes, 690 votes are needed to win.
# Red wasted 196 votes and blue wasted 495 votes.
#
# With 355 red votes and 288 blue votes, 322 votes are needed to win.
# Red wasted 33 votes and blue wasted 288 votes.
#
# With 1406 red votes and 613 blue votes, 1010 votes are needed to win.
# Red wasted 396 votes and blue wasted 613 votes.
#
# With 799 red votes and 335 blue votes, 568 votes are needed to win.
# Red wasted 231 votes and blue wasted 335 votes.
#
# With 142 red votes and 284 blue votes, 214 votes are needed to win.
# Red wasted 142 votes and blue wasted 70 votes.
#
# With 795 red votes and 340 blue votes, 568 votes are needed to win.
# Red wasted 227 votes and blue wasted 340 votes.
#
# With 1042 red votes and 308 blue votes, 676 votes are needed to win.
# Red wasted 366 votes and blue wasted 308 votes.
#
# With 488 red votes and 354 blue votes, 422 votes are needed to win.
# Red wasted 66 votes and blue wasted 354 votes.
#
# With 1216 red votes and 436 blue votes, 827 votes are needed to win.
# Red wasted 389 votes and blue wasted 436 votes.
#
# With 116 red votes and 530 blue votes, 324 votes are needed to win.
# Red wasted 116 votes and blue wasted 206 votes.
#
# With 1086 red votes and 240 blue votes, 664 votes are needed to win.
# Red wasted 422 votes and blue wasted 240 votes.
#
# With 132 red votes and 131 blue votes, 132 votes are needed to win.
# Red wasted 132 votes and blue wasted -1 votes.
#
# With 734 red votes and 185 blue votes, 460 votes are needed to win.
# Red wasted 274 votes and blue wasted 185 votes.
#
# With 726 red votes and 408 blue votes, 568 votes are needed to win.
# Red wasted 158 votes and blue wasted 408 votes.
#
# With 236 red votes and 224 blue votes, 231 votes are needed to win.
# Red wasted 5 votes and blue wasted 224 votes.
#
# With 767 red votes and 525 blue votes, 647 votes are needed to win.
# Red wasted 120 votes and blue wasted 525 votes.
#
# With 45 red votes and 147 blue votes, 97 votes are needed to win.
# Red wasted 45 votes and blue wasted 50 votes.
#
# With 717 red votes and 423 blue votes, 571 votes are needed to win.
# Red wasted 146 votes and blue wasted 423 votes.
#
# With 400 red votes and 157 blue votes, 278 votes are needed to win.
# Red wasted 122 votes and blue wasted 157 votes.
#
# With 687 red votes and 347 blue votes, 518 votes are needed to win.
# Red wasted 169 votes and blue wasted 347 votes.
#
# With 769 red votes and 453 blue votes, 612 votes are needed to win.
# Red wasted 157 votes and blue wasted 453 votes.
#
# With 77 red votes and 756 blue votes, 416 votes are needed to win.
# Red wasted 77 votes and blue wasted 340 votes.
#
# With 1358 red votes and 454 blue votes, 907 votes are needed to win.
# Red wasted 451 votes and blue wasted 454 votes.
#
# With 395 red votes and 198 blue votes, 296 votes are needed to win.
# Red wasted 99 votes and blue wasted 198 votes.
#
# With 85 red votes and 632 blue votes, 358 votes are needed to win.
# Red wasted 85 votes and blue wasted 274 votes.
#
# With 870 red votes and 249 blue votes, 560 votes are needed to win.
# Red wasted 310 votes and blue wasted 249 votes.
#
# With 661 red votes and 191 blue votes, 427 votes are needed to win.
# Red wasted 234 votes and blue wasted 191 votes.
#
# With 490 red votes and 791 blue votes, 640 votes are needed to win.
# Red wasted 490 votes and blue wasted 151 votes.
#
# With 1214 red votes and 453 blue votes, 834 votes are needed to win.
# Red wasted 380 votes and blue wasted 453 votes.
#
# With 135 red votes and 354 blue votes, 244 votes are needed to win.
# Red wasted 135 votes and blue wasted 110 votes.
#
# With 504 red votes and 340 blue votes, 423 votes are needed to win.
# Red wasted 81 votes and blue wasted 340 votes.
#
# With 156 red votes and 244 blue votes, 201 votes are needed to win.
# Red wasted 156 votes and blue wasted 43 votes.
#
# With 309 red votes and 1694 blue votes, 1002 votes are needed to win.
# Red wasted 309 votes and blue wasted 692 votes.
#
# With 32 red votes and 641 blue votes, 336 votes are needed to win.
# Red wasted 32 votes and blue wasted 305 votes.
#
# With 54 red votes and 543 blue votes, 298 votes are needed to win.
# Red wasted 54 votes and blue wasted 245 votes.
#
# With 420 red votes and 93 blue votes, 256 votes are needed to win.
# Red wasted 164 votes and blue wasted 93 votes.
#
# With 511 red votes and 339 blue votes, 426 votes are needed to win.
# Red wasted 85 votes and blue wasted 339 votes.
#
# With 713 red votes and 799 blue votes, 757 votes are needed to win.
# Red wasted 713 votes and blue wasted 42 votes.
#
# With 440 red votes and 1154 blue votes, 798 votes are needed to win.
# Red wasted 440 votes and blue wasted 356 votes.
#
# With 767 red votes and 917 blue votes, 843 votes are needed to win.
# Red wasted 767 votes and blue wasted 74 votes.
#
# With 424 red votes and 338 blue votes, 382 votes are needed to win.
# Red wasted 42 votes and blue wasted 338 votes.
#
# With 174 red votes and 95 blue votes, 134 votes are needed to win.
# Red wasted 40 votes and blue wasted 95 votes.
#
# With 65 red votes and 26 blue votes, 46 votes are needed to win.
# Red wasted 19 votes and blue wasted 26 votes.
#
# With 904 red votes and 412 blue votes, 659 votes are needed to win.
# Red wasted 245 votes and blue wasted 412 votes.
#
# With 176 red votes and 238 blue votes, 208 votes are needed to win.
# Red wasted 176 votes and blue wasted 30 votes.
#
# With 171 red votes and 154 blue votes, 162 votes are needed to win.
# Red wasted 9 votes and blue wasted 154 votes.
#
# With 586 red votes and 269 blue votes, 428 votes are needed to win.
# Red wasted 158 votes and blue wasted 269 votes.
#
# With 291 red votes and 469 blue votes, 381 votes are needed to win.
# Red wasted 291 votes and blue wasted 88 votes.
#
# With 1142 red votes and 380 blue votes, 762 votes are needed to win.
# Red wasted 380 votes and blue wasted 380 votes.
#
# With 608 red votes and 393 blue votes, 500 votes are needed to win.
# Red wasted 108 votes and blue wasted 393 votes.
#
# With 558 red votes and 627 blue votes, 592 votes are needed to win.
# Red wasted 558 votes and blue wasted 35 votes.
#
# With 851 red votes and 484 blue votes, 668 votes are needed to win.
# Red wasted 183 votes and blue wasted 484 votes.
#
# With 935 red votes and 562 blue votes, 748 votes are needed to win.
# Red wasted 187 votes and blue wasted 562 votes.
#
# With 959 red votes and 558 blue votes, 758 votes are needed to win.
# Red wasted 201 votes and blue wasted 558 votes.
#
# With 792 red votes and 381 blue votes, 586 votes are needed to win.
# Red wasted 206 votes and blue wasted 381 votes.
#
# With 661 red votes and 470 blue votes, 566 votes are needed to win.
# Red wasted 95 votes and blue wasted 470 votes.
#
# With 434 red votes and 166 blue votes, 301 votes are needed to win.
# Red wasted 133 votes and blue wasted 166 votes.
#
# With 1825 red votes and 704 blue votes, 1264 votes are needed to win.
# Red wasted 561 votes and blue wasted 704 votes.
#
# With 239 red votes and 55 blue votes, 148 votes are needed to win.
# Red wasted 91 votes and blue wasted 55 votes.
#
# With 67 red votes and 11 blue votes, 40 votes are needed to win.
# Red wasted 27 votes and blue wasted 11 votes.
#
# With 257 red votes and 61 blue votes, 160 votes are needed to win.
# Red wasted 97 votes and blue wasted 61 votes.
#
# With 229 red votes and 56 blue votes, 142 votes are needed to win.
# Red wasted 87 votes and blue wasted 56 votes.
#
# With 398 red votes and 176 blue votes, 288 votes are needed to win.
# Red wasted 110 votes and blue wasted 176 votes.
#
# With 133 red votes and 30 blue votes, 82 votes are needed to win.
# Red wasted 51 votes and blue wasted 30 votes.
#
# With 133 red votes and 9 blue votes, 72 votes are needed to win.
# Red wasted 61 votes and blue wasted 9 votes.
#
# With 456 red votes and 230 blue votes, 344 votes are needed to win.
# Red wasted 112 votes and blue wasted 230 votes.
#
# With 347 red votes and 143 blue votes, 246 votes are needed to win.
# Red wasted 101 votes and blue wasted 143 votes.
#
# With 408 red votes and 214 blue votes, 312 votes are needed to win.
# Red wasted 96 votes and blue wasted 214 votes.
#
# With 767 red votes and 730 blue votes, 748 votes are needed to win.
# Red wasted 19 votes and blue wasted 730 votes.
#
# With 34 red votes and 503 blue votes, 268 votes are needed to win.
# Red wasted 34 votes and blue wasted 235 votes.
#
# With 95 red votes and 152 blue votes, 124 votes are needed to win.
# Red wasted 95 votes and blue wasted 28 votes.
#
# With 293 red votes and 360 blue votes, 326 votes are needed to win.
# Red wasted 293 votes and blue wasted 34 votes.
#
# With 115 red votes and 380 blue votes, 248 votes are needed to win.
# Red wasted 115 votes and blue wasted 132 votes.
#
# With 45 red votes and 512 blue votes, 278 votes are needed to win.
# Red wasted 45 votes and blue wasted 234 votes.
#
# With 86 red votes and 295 blue votes, 190 votes are needed to win.
# Red wasted 86 votes and blue wasted 105 votes.
#
# With 9 red votes and 414 blue votes, 212 votes are needed to win.
# Red wasted 9 votes and blue wasted 202 votes.
#
# With 238 red votes and 252 blue votes, 246 votes are needed to win.
# Red wasted 238 votes and blue wasted 6 votes.
#
# With 5 red votes and 318 blue votes, 162 votes are needed to win.
# Red wasted 5 votes and blue wasted 156 votes.
#
# With 89 red votes and 95 blue votes, 93 votes are needed to win.
# Red wasted 89 votes and blue wasted 2 votes.
#
# With 215 red votes and 118 blue votes, 166 votes are needed to win.
# Red wasted 49 votes and blue wasted 118 votes.
#
# With 230 red votes and 229 blue votes, 230 votes are needed to win.
# Red wasted 230 votes and blue wasted -1 votes.
#
# With 95 red votes and 468 blue votes, 282 votes are needed to win.
# Red wasted 95 votes and blue wasted 186 votes.
#
# With 18 red votes and 619 blue votes, 318 votes are needed to win.
# Red wasted 18 votes and blue wasted 301 votes.
#
# With 184 red votes and 1198 blue votes, 692 votes are needed to win.
# Red wasted 184 votes and blue wasted 506 votes.
#
# With 753 red votes and 821 blue votes, 788 votes are needed to win.
# Red wasted 753 votes and blue wasted 33 votes.
#
# With 113 red votes and 757 blue votes, 436 votes are needed to win.
# Red wasted 113 votes and blue wasted 321 votes.
#
# With 69 red votes and 596 blue votes, 332 votes are needed to win.
# Red wasted 69 votes and blue wasted 264 votes.
#
# With 179 red votes and 647 blue votes, 414 votes are needed to win.
# Red wasted 179 votes and blue wasted 233 votes.
#
# With 50 red votes and 72 blue votes, 62 votes are needed to win.
# Red wasted 50 votes and blue wasted 10 votes.
#
# With 195 red votes and 437 blue votes, 317 votes are needed to win.
# Red wasted 195 votes and blue wasted 120 votes.
#
# With 1025 red votes and 644 blue votes, 834 votes are needed to win.
# Red wasted 191 votes and blue wasted 644 votes.
#
# With 259 red votes and 252 blue votes, 256 votes are needed to win.
# Red wasted 3 votes and blue wasted 252 votes.
#
# With 160 red votes and 479 blue votes, 320 votes are needed to win.
# Red wasted 160 votes and blue wasted 159 votes.
#
# With 93 red votes and 217 blue votes, 156 votes are needed to win.
# Red wasted 93 votes and blue wasted 61 votes.
#
# With 82 red votes and 316 blue votes, 200 votes are needed to win.
# Red wasted 82 votes and blue wasted 116 votes.
#
# With 64 red votes and 56 blue votes, 61 votes are needed to win.
# Red wasted 3 votes and blue wasted 56 votes.
#
# With 23 red votes and 86 blue votes, 54 votes are needed to win.
# Red wasted 23 votes and blue wasted 32 votes.
#
# With 41 red votes and 422 blue votes, 232 votes are needed to win.
# Red wasted 41 votes and blue wasted 190 votes.
#
# With 86 red votes and 77 blue votes, 82 votes are needed to win.
# Red wasted 4 votes and blue wasted 77 votes.
#
# With 107 red votes and 109 blue votes, 109 votes are needed to win.
# Red wasted 107 votes and blue wasted 0 votes.
#
# With 45 red votes and 49 blue votes, 48 votes are needed to win.
# Red wasted 45 votes and blue wasted 1 votes.
#
# With 80 red votes and 148 blue votes, 115 votes are needed to win.
# Red wasted 80 votes and blue wasted 33 votes.
#
# With 90 red votes and 129 blue votes, 110 votes are needed to win.
# Red wasted 90 votes and blue wasted 19 votes.
#
# With 117 red votes and 76 blue votes, 96 votes are needed to win.
# Red wasted 21 votes and blue wasted 76 votes.
#
# With 27 red votes and 71 blue votes, 50 votes are needed to win.
# Red wasted 27 votes and blue wasted 21 votes.
#
# With 163 red votes and 119 blue votes, 142 votes are needed to win.
# Red wasted 21 votes and blue wasted 119 votes.
#
# With 88 red votes and 35 blue votes, 62 votes are needed to win.
# Red wasted 26 votes and blue wasted 35 votes.
#
# With 63 red votes and 65 blue votes, 65 votes are needed to win.
# Red wasted 63 votes and blue wasted 0 votes.
#
# With 324 red votes and 307 blue votes, 316 votes are needed to win.
# Red wasted 8 votes and blue wasted 307 votes.
#
# With 404 red votes and 518 blue votes, 462 votes are needed to win.
# Red wasted 404 votes and blue wasted 56 votes.
#
# With 281 red votes and 153 blue votes, 218 votes are needed to win.
# Red wasted 63 votes and blue wasted 153 votes.
#
# With 273 red votes and 146 blue votes, 210 votes are needed to win.
# Red wasted 63 votes and blue wasted 146 votes.
#
# With 162 red votes and 141 blue votes, 152 votes are needed to win.
# Red wasted 10 votes and blue wasted 141 votes.
#
# With 299 red votes and 149 blue votes, 225 votes are needed to win.
# Red wasted 74 votes and blue wasted 149 votes.
#
# With 481 red votes and 397 blue votes, 440 votes are needed to win.
# Red wasted 41 votes and blue wasted 397 votes.
#
# With 319 red votes and 388 blue votes, 354 votes are needed to win.
# Red wasted 319 votes and blue wasted 34 votes.
#
# With 433 red votes and 277 blue votes, 356 votes are needed to win.
# Red wasted 77 votes and blue wasted 277 votes.
#
# With 319 red votes and 146 blue votes, 232 votes are needed to win.
# Red wasted 87 votes and blue wasted 146 votes.
#
# With 145 red votes and 189 blue votes, 168 votes are needed to win.
# Red wasted 145 votes and blue wasted 21 votes.
#
# With 377 red votes and 345 blue votes, 362 votes are needed to win.
# Red wasted 15 votes and blue wasted 345 votes.
#
# With 368 red votes and 227 blue votes, 298 votes are needed to win.
# Red wasted 70 votes and blue wasted 227 votes.
#
# With 110 red votes and 170 blue votes, 141 votes are needed to win.
# Red wasted 110 votes and blue wasted 29 votes.
#
# With 54 red votes and 32 blue votes, 44 votes are needed to win.
# Red wasted 10 votes and blue wasted 32 votes.
#
# With 597 red votes and 408 blue votes, 502 votes are needed to win.
# Red wasted 95 votes and blue wasted 408 votes.
#
# With 451 red votes and 437 blue votes, 445 votes are needed to win.
# Red wasted 6 votes and blue wasted 437 votes.
#
# With 293 red votes and 214 blue votes, 254 votes are needed to win.
# Red wasted 39 votes and blue wasted 214 votes.
#
# With 188 red votes and 447 blue votes, 318 votes are needed to win.
# Red wasted 188 votes and blue wasted 129 votes.
#
# With 568 red votes and 172 blue votes, 371 votes are needed to win.
# Red wasted 197 votes and blue wasted 172 votes.
#
# With 249 red votes and 41 blue votes, 146 votes are needed to win.
# Red wasted 103 votes and blue wasted 41 votes.
#
# With 66 red votes and 122 blue votes, 95 votes are needed to win.
# Red wasted 66 votes and blue wasted 27 votes.
#
# With 54 red votes and 79 blue votes, 66 votes are needed to win.
# Red wasted 54 votes and blue wasted 13 votes.
#
# With 374 red votes and 340 blue votes, 358 votes are needed to win.
# Red wasted 16 votes and blue wasted 340 votes.
#
# With 2 red votes and 238 blue votes, 121 votes are needed to win.
# Red wasted 2 votes and blue wasted 117 votes.
#
# With 28 red votes and 753 blue votes, 390 votes are needed to win.
# Red wasted 28 votes and blue wasted 363 votes.
#
# With 255 red votes and 104 blue votes, 180 votes are needed to win.
# Red wasted 75 votes and blue wasted 104 votes.
#
# With 263 red votes and 128 blue votes, 196 votes are needed to win.
# Red wasted 67 votes and blue wasted 128 votes.
#
# With 197 red votes and 129 blue votes, 164 votes are needed to win.
# Red wasted 33 votes and blue wasted 129 votes.
#
# With 305 red votes and 392 blue votes, 348 votes are needed to win.
# Red wasted 305 votes and blue wasted 44 votes.
#
# With 372 red votes and 283 blue votes, 328 votes are needed to win.
# Red wasted 44 votes and blue wasted 283 votes.
#
# With 179 red votes and 214 blue votes, 196 votes are needed to win.
# Red wasted 179 votes and blue wasted 18 votes.
#
# With 473 red votes and 715 blue votes, 595 votes are needed to win.
# Red wasted 473 votes and blue wasted 120 votes.
#
# With 680 red votes and 1711 blue votes, 1196 votes are needed to win.
# Red wasted 680 votes and blue wasted 515 votes.
#
# With 612 red votes and 977 blue votes, 794 votes are needed to win.
# Red wasted 612 votes and blue wasted 183 votes.
#
# With 389 red votes and 974 blue votes, 682 votes are needed to win.
# Red wasted 389 votes and blue wasted 292 votes.
#
# With 54 red votes and 1220 blue votes, 638 votes are needed to win.
# Red wasted 54 votes and blue wasted 582 votes.
#
# With 7 red votes and 288 blue votes, 148 votes are needed to win.
# Red wasted 7 votes and blue wasted 140 votes.
#
# With 384 red votes and 936 blue votes, 661 votes are needed to win.
# Red wasted 384 votes and blue wasted 275 votes.
#
# With 160 red votes and 704 blue votes, 433 votes are needed to win.
# Red wasted 160 votes and blue wasted 271 votes.
#
# With 748 red votes and 478 blue votes, 614 votes are needed to win.
# Red wasted 134 votes and blue wasted 478 votes.
#
# With 164 red votes and 790 blue votes, 478 votes are needed to win.
# Red wasted 164 votes and blue wasted 312 votes.
#
# With 47 red votes and 558 blue votes, 302 votes are needed to win.
# Red wasted 47 votes and blue wasted 256 votes.
#
# With 96 red votes and 634 blue votes, 366 votes are needed to win.
# Red wasted 96 votes and blue wasted 268 votes.
#
# With 166 red votes and 207 blue votes, 186 votes are needed to win.
# Red wasted 166 votes and blue wasted 21 votes.
#
# With 286 red votes and 318 blue votes, 303 votes are needed to win.
# Red wasted 286 votes and blue wasted 15 votes.
#
# With 299 red votes and 219 blue votes, 260 votes are needed to win.
# Red wasted 39 votes and blue wasted 219 votes.
#
# With 737 red votes and 452 blue votes, 594 votes are needed to win.
# Red wasted 143 votes and blue wasted 452 votes.
#
# With 95 red votes and 255 blue votes, 176 votes are needed to win.
# Red wasted 95 votes and blue wasted 79 votes.
#
# With 218 red votes and 518 blue votes, 369 votes are needed to win.
# Red wasted 218 votes and blue wasted 149 votes.
#
# With 8 red votes and 398 blue votes, 204 votes are needed to win.
# Red wasted 8 votes and blue wasted 194 votes.
#
# With 278 red votes and 460 blue votes, 370 votes are needed to win.
# Red wasted 278 votes and blue wasted 90 votes.
#
# With 217 red votes and 178 blue votes, 198 votes are needed to win.
# Red wasted 19 votes and blue wasted 178 votes.
#
# With 181 red votes and 107 blue votes, 145 votes are needed to win.
# Red wasted 36 votes and blue wasted 107 votes.
#
# With 91 red votes and 230 blue votes, 160 votes are needed to win.
# Red wasted 91 votes and blue wasted 70 votes.
#
# With 165 red votes and 98 blue votes, 132 votes are needed to win.
# Red wasted 33 votes and blue wasted 98 votes.
#
# With 97 red votes and 29 blue votes, 64 votes are needed to win.
# Red wasted 33 votes and blue wasted 29 votes.
#
# With 285 red votes and 232 blue votes, 258 votes are needed to win.
# Red wasted 27 votes and blue wasted 232 votes.
#
# With 198 red votes and 68 blue votes, 134 votes are needed to win.
# Red wasted 64 votes and blue wasted 68 votes.
#
# With 145 red votes and 61 blue votes, 104 votes are needed to win.
# Red wasted 41 votes and blue wasted 61 votes.
#
# With 78 red votes and 50 blue votes, 65 votes are needed to win.
# Red wasted 13 votes and blue wasted 50 votes.
#
# With 202 red votes and 55 blue votes, 128 votes are needed to win.
# Red wasted 74 votes and blue wasted 55 votes.
#
# With 71 red votes and 43 blue votes, 58 votes are needed to win.
# Red wasted 13 votes and blue wasted 43 votes.
#
# With 119 red votes and 49 blue votes, 85 votes are needed to win.
# Red wasted 34 votes and blue wasted 49 votes.
#
# With 289 red votes and 261 blue votes, 276 votes are needed to win.
# Red wasted 13 votes and blue wasted 261 votes.
#
# With 140 red votes and 199 blue votes, 170 votes are needed to win.
# Red wasted 140 votes and blue wasted 29 votes.
#
# With 45 red votes and 110 blue votes, 78 votes are needed to win.
# Red wasted 45 votes and blue wasted 32 votes.
#
# With 268 red votes and 181 blue votes, 224 votes are needed to win.
# Red wasted 44 votes and blue wasted 181 votes.
#
# With 271 red votes and 323 blue votes, 298 votes are needed to win.
# Red wasted 271 votes and blue wasted 25 votes.
#
# With 82 red votes and 81 blue votes, 82 votes are needed to win.
# Red wasted 82 votes and blue wasted -1 votes.
#
# With 217 red votes and 194 blue votes, 206 votes are needed to win.
# Red wasted 11 votes and blue wasted 194 votes.
#
# With 379 red votes and 392 blue votes, 386 votes are needed to win.
# Red wasted 379 votes and blue wasted 6 votes.
#
# With 61 red votes and 81 blue votes, 72 votes are needed to win.
# Red wasted 61 votes and blue wasted 9 votes.
#
# With 20 red votes and 46 blue votes, 34 votes are needed to win.
# Red wasted 20 votes and blue wasted 12 votes.
#
# With 973 red votes and 806 blue votes, 890 votes are needed to win.
# Red wasted 83 votes and blue wasted 806 votes.
#
# With 792 red votes and 647 blue votes, 720 votes are needed to win.
# Red wasted 72 votes and blue wasted 647 votes.
#
# With 1092 red votes and 682 blue votes, 888 votes are needed to win.
# Red wasted 204 votes and blue wasted 682 votes.
#
# With 499 red votes and 198 blue votes, 348 votes are needed to win.
# Red wasted 151 votes and blue wasted 198 votes.
#
# With 184 red votes and 115 blue votes, 150 votes are needed to win.
# Red wasted 34 votes and blue wasted 115 votes.
#
# With 247 red votes and 38 blue votes, 142 votes are needed to win.
# Red wasted 105 votes and blue wasted 38 votes.
#
# With 288 red votes and 364 blue votes, 327 votes are needed to win.
# Red wasted 288 votes and blue wasted 37 votes.
#
# With 171 red votes and 148 blue votes, 160 votes are needed to win.
# Red wasted 11 votes and blue wasted 148 votes.
#
# With 371 red votes and 99 blue votes, 236 votes are needed to win.
# Red wasted 135 votes and blue wasted 99 votes.
#
# With 235 red votes and 200 blue votes, 218 votes are needed to win.
# Red wasted 17 votes and blue wasted 200 votes.
#
# With 271 red votes and 545 blue votes, 409 votes are needed to win.
# Red wasted 271 votes and blue wasted 136 votes.
#
# With 698 red votes and 625 blue votes, 662 votes are needed to win.
# Red wasted 36 votes and blue wasted 625 votes.
#
# With 233 red votes and 97 blue votes, 166 votes are needed to win.
# Red wasted 67 votes and blue wasted 97 votes.
#
# With 144 red votes and 198 blue votes, 172 votes are needed to win.
# Red wasted 144 votes and blue wasted 26 votes.
#
# With 333 red votes and 65 blue votes, 200 votes are needed to win.
# Red wasted 133 votes and blue wasted 65 votes.
#
# With 282 red votes and 288 blue votes, 286 votes are needed to win.
# Red wasted 282 votes and blue wasted 2 votes.
#
# With 257 red votes and 72 blue votes, 164 votes are needed to win.
# Red wasted 93 votes and blue wasted 72 votes.
#
# With 166 red votes and 37 blue votes, 102 votes are needed to win.
# Red wasted 64 votes and blue wasted 37 votes.
#
# With 360 red votes and 93 blue votes, 226 votes are needed to win.
# Red wasted 134 votes and blue wasted 93 votes.
#
# With 7 red votes and 258 blue votes, 132 votes are needed to win.
# Red wasted 7 votes and blue wasted 126 votes.
#
# With 88 red votes and 579 blue votes, 334 votes are needed to win.
# Red wasted 88 votes and blue wasted 245 votes.
#
# With 40 red votes and 620 blue votes, 331 votes are needed to win.
# Red wasted 40 votes and blue wasted 289 votes.
#
# With 38 red votes and 327 blue votes, 182 votes are needed to win.
# Red wasted 38 votes and blue wasted 145 votes.
#
# With 27 red votes and 322 blue votes, 174 votes are needed to win.
# Red wasted 27 votes and blue wasted 148 votes.
#
# With 43 red votes and 459 blue votes, 252 votes are needed to win.
# Red wasted 43 votes and blue wasted 207 votes.
#
# With 768 red votes and 241 blue votes, 504 votes are needed to win.
# Red wasted 264 votes and blue wasted 241 votes.
#
# With 466 red votes and 110 blue votes, 289 votes are needed to win.
# Red wasted 177 votes and blue wasted 110 votes.
#
# With 601 red votes and 182 blue votes, 392 votes are needed to win.
# Red wasted 209 votes and blue wasted 182 votes.
#
# With 971 red votes and 196 blue votes, 584 votes are needed to win.
# Red wasted 387 votes and blue wasted 196 votes.
#
# With 439 red votes and 91 blue votes, 266 votes are needed to win.
# Red wasted 173 votes and blue wasted 91 votes.
#
# With 694 red votes and 278 blue votes, 487 votes are needed to win.
# Red wasted 207 votes and blue wasted 278 votes.
#
# With 695 red votes and 242 blue votes, 468 votes are needed to win.
# Red wasted 227 votes and blue wasted 242 votes.
#
# With 231 red votes and 72 blue votes, 152 votes are needed to win.
# Red wasted 79 votes and blue wasted 72 votes.
#
# With 479 red votes and 95 blue votes, 288 votes are needed to win.
# Red wasted 191 votes and blue wasted 95 votes.
#
# With 431 red votes and 41 blue votes, 237 votes are needed to win.
# Red wasted 194 votes and blue wasted 41 votes.
#
# With 644 red votes and 149 blue votes, 396 votes are needed to win.
# Red wasted 248 votes and blue wasted 149 votes.
#
# With 61 red votes and 26 blue votes, 44 votes are needed to win.
# Red wasted 17 votes and blue wasted 26 votes.
#
# With 193 red votes and 34 blue votes, 114 votes are needed to win.
# Red wasted 79 votes and blue wasted 34 votes.
#
# With 996 red votes and 410 blue votes, 704 votes are needed to win.
# Red wasted 292 votes and blue wasted 410 votes.
#
# With 245 red votes and 155 blue votes, 201 votes are needed to win.
# Red wasted 44 votes and blue wasted 155 votes.
#
# With 130 red votes and 165 blue votes, 148 votes are needed to win.
# Red wasted 130 votes and blue wasted 17 votes.
#
# With 215 red votes and 179 blue votes, 198 votes are needed to win.
# Red wasted 17 votes and blue wasted 179 votes.
#
# With 230 red votes and 79 blue votes, 154 votes are needed to win.
# Red wasted 76 votes and blue wasted 79 votes.
#
# With 745 red votes and 651 blue votes, 699 votes are needed to win.
# Red wasted 46 votes and blue wasted 651 votes.
#
# With 513 red votes and 539 blue votes, 527 votes are needed to win.
# Red wasted 513 votes and blue wasted 12 votes.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-2d567465a669> in <module>()
#       1 for pt in data:
#       2     (red, blue) = votes_cast_for_senator(pt)
# ----> 3     thresh = threshold((red, blue))
#       4     (red_wasted, blue_wasted) = wasted_votes(pt)
#       5
#
# <ipython-input-4-b4934a53f7cb> in threshold(votes)
#       1 def threshold(votes):
#       2     if votes[0] == votes[1]:
# ----> 3         raise Exception("The Efficiency Gap is undefined in the case of a tie")
#       4     half = sum(votes)/2
#       5     if round(half) == half:
#
# Exception: The Efficiency Gap is undefined in the case of a tie

# %%
def net_wasted_votes(data):
    total_red_wasted = 0
    total_blue_wasted = 0
    for ii, pt in enumerate(data):
        (red_wasted, blue_wasted) = wasted_votes(pt)
        total_red_wasted  += red_wasted
        total_blue_wasted += blue_wasted
    return total_red_wasted - total_blue_wasted

# %%
def total_votes_cast(data):
    total = 0
    for pt in data:
        total += sum(votes_cast_for_senator(pt))
    return total

# %%
def efficiency_gap(data):
    return net_wasted_votes(data)/total_votes_cast(data)

# %%
print('For all of North Carolina:')
print('Net Wasted Votes: ', net_wasted_votes(data))
gap = efficiency_gap(data)
print('Efficiency Gap: ', str(round(gap*100, 2)) + '%')
print('This fucked over the {}.\n'.format('Democrats' if gap<0 else 'Republicans'))

for district in range(1,14):
    precincts = [pt for pt in data if district==pt['properties']['con_districts']]
    print('District: ', district)
    print('Net Wasted Votes: ', net_wasted_votes(precincts))
    gap = efficiency_gap(precincts)
    print('Efficiency Gap: ', str(round(gap*100, 2)) + '%')
    print('This screwed over the {}.\n'.format('Democrats' if gap<0 else 'Republicans'))

# %% [markdown]
# #### The above method calculates the partial net wasted votes and sums them up. Does this calculate the same efficiency gap when summing total wasted votes?

# %%
def total_wasted_votes(district):
    red = sum([pt['properties']['sen_red'] for pt in district])
    blue= sum([pt['properties']['sen_blue'] for pt in district])
    if red==blue:
        return (0,0)
    
    thresh = threshold((red, blue))
    if red>thresh:
        red_wasted = red - thresh
        blue_wasted = blue
    else:
        blue_wasted = blue - thresh
        red_wasted = red
    
    return (red_wasted, blue_wasted, red+blue)

# %%
def efficiency_gap_from_total(data):
    (red_wasted, blue_wasted, total_votes) = total_wasted_votes(precincts)
    net_wasted = red_wasted-blue_wasted
    return (net_wasted, net_wasted/total_votes)

# %%
dem_gap = 0
rep_gap = 0
dem_dist = 0
rep_dist = 0
for district in range(1,14):
    precincts = [pt for pt in data if district==pt['properties']['con_districts']]
    (net_wasted, gap) = efficiency_gap_from_total(precincts)
    print('District: ', district)
    print('Net Wasted Votes: ', net_wasted)
    print('Efficiency Gap: ', str(round(gap*100, 2)) + '%')
    print('This screwed over the {}.\n'.format('Democrats' if gap<0 else 'Republicans'))
    
    if gap<0:
        dem_gap += gap
        dem_dist += 1
    else:
        rep_gap += gap
        rep_dist += 1

dem_gap = dem_gap/dem_dist
rep_gap = rep_gap/rep_dist
print('Average Efficiency Gap for Democrats in North Carolina: ', str(round(dem_gap*100, 2)) + '%')
print('Average Efficiency Gap for Republicans in North Carolina: ', str(round(rep_gap*100, 2)) + '%')

# %% [markdown]
# ## Recalculate to double check

# %%
import sys
path = '/Users/Joe/Documents/Metis/Projects/metis-05-kojak/python-scripts/'
sys.path.append(path)
from kojak import threshold as thr
from kojak import wasted_votes as wv

# %%
# Find wasted votes per district:
rep_wasted = []
dem_wasted = []
total_votes = 0
for district in range(1, 14):
    if district != 9:
        precincts = [pt for pt in data if pt['properties']['con_districts'] == district]
        rep_votes = 0
        dem_votes = 0
        for pt in precincts:
            rep_votes += pt['properties']['con_red_votes']
            dem_votes += pt['properties']['con_blue_votes']
            
        total_votes += rep_votes + dem_votes
        
        thresh = thr(rep_votes + dem_votes)
        rep_wasted.append(wv(rep_votes, thresh))
        dem_wasted.append(wv(dem_votes, thresh))

# %%
rep_wasted
# Out:
# [38147,
#  16693,
#  24216,
#  40967,
#  23720,
#  21821,
#  25469,
#  25172,
#  21566,
#  26812,
#  77692,
#  16752]

# %%
dem_wasted
# Out:
# [27894,
#  61134,
#  44139,
#  32040,
#  79497,
#  95330,
#  72564,
#  55099,
#  64892,
#  74010,
#  84839,
#  71158]

# %%
total_votes
# Out:
# 2243258

# %%
gap = (sum(rep_wasted) - sum(dem_wasted))/total_votes

# %%
gap
# Out:
# -0.1799030695533015
